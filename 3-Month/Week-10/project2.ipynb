# %% [markdown]
# # Client Project – Customer Segmentation

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("Mall_Customers.csv")

# %%
X = df[["Annual Income (k$)", "Spending Score (1-100)"]]

# %%
kmeans = KMeans(n_clusters=5, random_state=42, n_init=10)
df["Cluster"] = kmeans.fit_predict(X)

# %% [markdown]
# Visualization

# %%
plt.figure(figsize=(8,6))
plt.scatter(df["Annual Income (k$)"], df["Spending Score (1-100)"],
            c=df["Cluster"], cmap="viridis", s=50)
plt.title("Customer Segmentation (K-Means)")
plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score (1-100)")
plt.savefig("customer_segmentation.png")
plt.show()

# %%
with open("results_customer_segmentation.txt", "w") as f:
    f.write("Customer Segmentation Results\n")
    f.write("Number of clusters: 5\n")
    f.write("Cluster Centers:\n")
    f.write(str(kmeans.cluster_centers_) + "\n")
    f.write("Saved visualization: customer_segmentation.png\n")
    f.write("Saved clustered data: customer_clusters.csv\n")
